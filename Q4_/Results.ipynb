# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Output_files = pd.read_csv("Output_file_names.csv",delimiter=",",header=None).to_numpy()
Output_files = np.squeeze(Output_files)
Output_files = Output_files.tolist()

# %%
for file_name in Output_files:
    print(file_name)
# Out:
# Q4_b_Grid_Points_Euler_Implicit_Solution.csv
# Q4_b_Euler_Implicit_Solution.csv

# %%
fig = plt.figure()
x = pd.read_csv("Q4_b_Grid_Points_Euler_Implicit_Solution.csv", delimiter = ",",header=None).to_numpy()
y = pd.read_csv("Q4_b_Euler_Implicit_Solution.csv", delimiter = ",",header=None).to_numpy()

plt.plot(x,y)
plt.title(r"$\frac{dy}{dx} = -200000y + 200000e^{-x} - e^{-x}$")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.show()
fig.savefig("Q4_b_Euler_Implicit_Solution.png",dpi = 500, bbox_inches = 'tight')
